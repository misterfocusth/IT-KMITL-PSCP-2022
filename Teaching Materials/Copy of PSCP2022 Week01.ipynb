# %% [markdown]
# PSCP2022 Week01: Introduction
# ===
# Chotipat Pornavalai
#
# chotipat@it.kmitl.ac.th

# %% [markdown]
# **Syllabus:** https://syllabus.kmitl.ac.th/share/course-syllabus?id=65-1-06066303-1
#
# **Facebook Group:** https://www.facebook.com/groups/1027048434620800
#
# ![Screen Shot 2565-08-07 at 22.56.01.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Course Objective**

# %% [markdown]
# ![Screen Shot 2565-08-06 at 19.38.17.png](data:image/png;base64,...)

# %% [markdown]
# **Textbooks:**
#
# Think Python 2nd Edition: https://greenteapress.com/wp/think-python-2e/
#
#
# <img src="http://greenteapress.com/thinkpython2/think_python2_medium.jpg" alt="Think Python 2nd Edition" width=500>

# %% [markdown]
# **Topics**
#
# ![Screen Shot 2565-08-06 at 19.35.36.png](data:image/png;base64,...)

# %% [markdown]
# "Hello World" in Python
# ===
# When programmers are learning a new language, we tend to write a one-line program that prints some version of the message "Hello World!". This is a simple program that shows whether your computer is properly set up to run Python programs.

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# If it works, congratulations! You just ran your first Python program.

# %% [markdown]
# **Exercise 1**: Write a print statement to hello Moon.

# %%
###exercise 1
print("hello Moon.")

# %% [markdown]
# ---

# %% [markdown]
# Variables
# ===
# A variable holds a value.

# %% [markdown]
# Example
# ---

# %%
message = "Hello Python world!"
x = 5

# %% [markdown]
# A variable holds a value. You can change the value of a variable at any point.

# %%
print("Hello Python world!")
print(message)
message = "Python is my favorite language!"
print(message)
# Out:
# Hello Python world!
# Hello Python world!
# Python is my favorite language!

# %% [markdown]
# Naming rules
# ---
# - Variables can only contain letters, numbers, and underscores. Variable names can start with a letter or an underscore, but can not start with a number.
# - Spaces are not allowed in variable names, so we use underscores instead of spaces. For example, use **student_name** instead of "student name".
# - You cannot use [Python keywords](http://docs.python.org/3/reference/lexical_analysis.html#keywords) as variable names.
# - Variable names should be descriptive, without being too long. For example mc_wheels is better than just "wheels", and number_of_wheels_on_a_motorcycle.
# - Be careful about using the lowercase letter l and the uppercase letter O in places where they could be confused with the numbers 1 and 0.

# %% [markdown]
# NameError
# ---
# There is one common error when using variables, that you will almost certainly encounter at some point. Take a look at this code, and see if you can figure out why it causes an error.

# %%
message = "Thank you for sharing Python with the world, Guido!"
print(message)
# Out:
# Thank you for sharing Python with the world, Guido!

# %% [markdown]
# [Guido Van Rossum](https://en.wikipedia.org/wiki/Guido_van_Rossum)
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/e2/Guido-portrait-2014-drc.jpg" alt="Guido Van Rossum" width=200>

# %% [markdown]
# Let's look through this error message. First, we see it is a **NameError**. Then we see the file that caused the error, and a green arrow shows us what line in that file caused the error. Then we get some more specific feedback, that "name '**messege**' is not defined".
#
# You may have already spotted the source of the error. We spelled message two different ways. Python does not care whether we use the variable name "message" or "messege". Python only cares that the spellings of our variable names match every time we use them.
#
# We can fix NameErrors by making sure all of our variable names are spelled consistently.

# %%
###highlight on line 3 <- this line is a comment line.
message = "Thank you for sharing Python with the world, Guido!"
print(message)
# Out:
# Thank you for sharing Python with the world, Guido!

# %% [markdown]
# ---

# %% [markdown]
# Basic Strings
# ===
# Strings are sets of characters. Strings are easier to understand by looking at some examples.

# %% [markdown]
# Single and double quotes
# ---
# Strings are contained by either single or double quotes.

# %%
my_string = "This is a double-quoted string."
my_string = 'This is a single-quoted string.'

# %% [markdown]
# **Exercise 2**: Fix the error in the following cell

# %%
###exercise 2
message = 'Thank you for sharing Python with the world, Guido!'
print(message)
# Out:
# Thank you for sharing Python with the world, Guido!

# %% [markdown]
# To make strings that contain quotations.
#
# Ken Thompson once said, "One of my most productive days was throwing away 1000 lines of code"

# %%
quote =  'Ken Thompson once said, "One of my most productive days was throwing away 1000 lines of code"'
print(quote)
# Out:
# Ken Thompson once said, "One of my most productive days was throwing away 1000 lines of code"

# %% [markdown]
# [Ken Thompson](https://en.wikipedia.org/wiki/Ken_Thompson)
#
# <img src="https://www.invent.org/sites/default/files/styles/inductee_detail_media/public/inductees/2019-01/Thompson%2C%20Ken.jpg" alt="Ken Thompson" width=200>

# %% [markdown]
# **Exercise 3**: Write a print statement to print the following quote.
# > Linus Torvalds once said, 'Any program is only as good as it is useful.'

# %%
###exercise 3
linus_quote = "Linus Torvalds once said, 'Any program is only as good as it is useful.'"
print(linus_quote)
# Out:
# Linus Torvalds once said, 'Any program is only as good as it is useful.'

# %% [markdown]
# [Linus Torvalds](https://en.wikipedia.org/wiki/Linus_Torvalds)
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/LinuxCon_Europe_Linus_Torvalds_03_%28cropped%29.jpg" alt="My Image" width=200>

# %% [markdown]
# Changing case
# ---
# You can easily change the case of a string, to present it the way you want it to look.

# %%
first_name = 'eren'
print(first_name)
print(first_name.title())
# Out:
# eren
# Eren

# %% [markdown]
# It is often good to store data in lower case, and then change the case as you want to for presentation. This catches some TYpos. It also makes sure that 'eric', 'Eric', and 'ERIC' are not considered three different people.
#
# Some of the most common cases are lower, title, and upper.

# %%
first_name = 'eren'

print(first_name)
print(first_name.title())
print(first_name.upper())

first_name = 'Eren'
print(first_name.lower())

fullname = 'eren yeager'
print(fullname.title())
print(fullname.upper())
# Out:
# eren
# Eren
# EREN
# eren
# Eren Yeager
# EREN YEAGER

# %% [markdown]
# You will see this syntax quite often, where a variable name is followed by a dot and then the name of an action, followed by a set of parentheses. The parentheses may be empty, or they may contain some values.
#
# variable_name.action()
#
# In this example, the word "**action**" is the name of a **method**. A method is something that can be done to a variable. The methods 'lower', 'title', and 'upper' are all functions that have been written into the Python language, which do something to strings. Later on, you will learn to write your own methods.

# %% [markdown]
# Combining strings (concatenation)
# ---
# It is often very useful to be able to combine strings into a message or page element that we want to display. Again, this is easier to understand through an example.

# %%
first_name = 'ada'
last_name = 'lovelace'

full_name = first_name + ' ' + last_name

print(full_name.title())
# Out:
# Ada Lovelace

# %% [markdown]
# The plus sign combines two strings into one, which is called "concatenation". You can use as many plus signs as you want in composing messages. In fact, many web pages are written as giant strings which are put together through a long series of string concatenations.

# %%
first_name = 'ada'
last_name = 'lovelace'
full_name = first_name + ' ' + last_name

message = full_name.title() + ' ' + "was considered the world's first computer programmer."

print(message)
# Out:
# Ada Lovelace was considered the world's first computer programmer.

# %% [markdown]
# We also can do mathematical operation on a string using multiplication operator (*). For example:

# %%
print('Ada'*3)
print(3*'Ada')
# Out:
# AdaAdaAda
# AdaAdaAda

# %% [markdown]
# Beaware that, all the following statements are invalid. Why?

# %%
print('Ada'*3.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-eb180e0149db> in <module>
# ----> 1 print('Ada'*3.0)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print('Ada'+ 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-696bbba20fa9> in <module>
# ----> 1 print('Ada'+ 3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('Ada'*'3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b3be5b76326d> in <module>
# ----> 1 print('Ada'*'3')
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# [Ada Lovelace](https://en.wikipedia.org/wiki/Ada_Lovelace)
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/b7/Ada_Byron_daguerreotype_by_Antoine_Claudet_1843_or_1850_-_cropped.png" alt="Ada Lovelace" width=200>

# %% [markdown]
# Whitespace
# ---
# The term "whitespace" refers to characters that the computer is aware of, but are invisible to readers. The most common whitespace characters are spaces, tabs, and newlines.
#
# Spaces are easy to create, because you have been using them as long as you have been using computers. Tabs and newlines are represented by special character combinations.
#
# The two-character combination "\t" makes a tab appear in a string. Tabs can be used anywhere you like in a string.

# %%
print("Hello everyone!")
# Out:
# Hello everyone!

# %%
print("Hello everyone!")
print("Hello\teveryone!")
# Out:
# Hello everyone!
# Hello	everyone!

# %% [markdown]
# The combination "\n" makes a newline appear in a string. You can use newlines anywhere you like in a string.

# %%
print("Hello everyone!")
# Out:
# Hello everyone!

# %%
print("\nHello everyone!")
# Out:
# Hello everyone!

# %%
print("Hello \neveryone!")
# Out:
# Hello
# everyone!

# %%
print("\n\n\nHello everyone!")
# Out:
# Hello everyone!

# %% [markdown]
# **Exercise 7**: Print the following three line by only one print statement.
# > Hello everyone!<br>
# > Hello everyone!<br>
# > Hello everyone!<br>

# %%
###exercise 7
print("Hello everyone!\nHello everyone!\nHello everyone!")
print("Hello everyone!\n" * 3)
print("Hello everyone!", "Hello everyone!", "Hello everyone!", sep="\n")
# Out:
# Hello everyone!
# Hello everyone!
# Hello everyone!
# Hello everyone!
# Hello everyone!
# Hello everyone!
#
# Hello everyone!
# Hello everyone!
# Hello everyone!

# %% [markdown]
# The \ can be used to escape a character. For example, to print " in a string surrounded with ", we can use \\" to escape the ".

# %%
print(""")

# %%
print("\"")

# %% [markdown]
# **Exercise 8**: Write a print statement to print the following sentences. Also print " at the begining and end of this sentence.
#
# >"The backslash (\\) is a typographical mark used mainly in computing and is the mirror image of the common slash (/). It is sometimes called "escape character"."

# %%
###exercise 8
sentence = "\"The backslash (\) is a typographical mark used mainly in computing and is the mirror image of the common slash (/). It is sometimes called \"escape character\".\""
print(sentence)

# %% [markdown]
# ###Stripping whitespace
#
# Many times you will allow users to enter text into a box, and then you will read that text and use it. It is really easy for people to include extra whitespace at the beginning or end of their text. Whitespace includes spaces, tabs, and newlines.
#
# It is often a good idea to strip this whitespace from strings before you start working with them. For example, you might want to let people log in, and you probably want to treat 'eric ' as 'eric' when you are trying to see if I exist on your system.
#
# You can strip whitespace from the left side, the right side, or both sides of a string.

# %%
name = '     eren yeager '

print(name.lstrip())
print(name.rstrip())
print(name.strip())
# Out:
# eren yeager
#      eren yeager
# eren yeager

# %% [markdown]
# ---

# %% [markdown]
# Numbers
# ===
# Dealing with simple numerical data is fairly straightforward in Python, but there are a few things you should know about.

# %% [markdown]
# Integers
# ---
# You can do all of the basic operations with integers, and everything should behave as you expect. Addition and subtraction use the standard plus and minus symbols. Multiplication uses the asterisk, and division uses a forward slash. Exponents use two asterisks.

# %%
print(3+2)

# %%
print(3-2)

# %%
print(3*2)

# %%
print(3/2)

# %%
print(3**2)
print(9**0.5) # squareroot of 9 = 3.0

# %%
print(7//2)
# Out:
# 3

# %%
print(7%2)
# Out:
# 1

# %% [markdown]
# You can use parenthesis to modify the standard order of operations.

# %%
standard_order = 2+3*4
print(standard_order)
# Out:
# 14

# %%
my_order = (2+3)*4
print(my_order)
# Out:
# 20

# %% [markdown]
# You need to know about PEMDAS to understand the standard order of operations. Read [PEMDAS](https://en.wikipedia.org/wiki/Order_of_operations) on wikipedia.

# %% [markdown]
# **Exercise 9**: Write an expression to find a [euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance) between two points (P1 and P2) on the x-y axis graph. Suppose that P1 = (x1, y1) = (3, 4) and P2 = (x2, y2) = (8, -8).

# %%
###exercise 9
###add an expression on line 7
x1 = 3
y1 = 4
x2 = 8
y2 = -8
distance = ((x2 - x1) ** 2 + (y2 - y1) ** 2) ** 0.5
print(distance)
# Out:
# 13.0

# %% [markdown]
# Floating-Point numbers
# ---
# Floating-point numbers refer to any number with a decimal point. Most of the time, you can think of floating point numbers as decimals, and they will behave as you expect them to.

# %%
print(0.1+0.1)
# Out:
# 0.2

# %% [markdown]
# However, sometimes you will get an answer with an unexpectly long decimal part:

# %%
print(0.1+0.2)
# Out:
# 0.30000000000000004

# %%
0.3 == (0.1 + 0.2)
# Out:
# False

# %% [markdown]
# This happens because of the way computers represent numbers internally; this has nothing to do with Python itself. Basically, we are used to working in powers of ten, where one tenth plus two tenths is just three tenths. But computers work in powers of two. So your computer has to represent 0.1 in a power of two, and then 0.2 as a power of two, and express their sum as a power of two. There is no exact representation for 0.3 in powers of two, and we see that in the answer to 0.1+0.2.
#
# Python tries to hide this kind of stuff when possible. Don't worry about it much for now; just don't be surprised by it, and know that we will learn to clean up our results a little later on.
#
# You can also get the same kind of result with other operations.

# %%
print(3*0.1)

# %% [markdown]
# Integers in Python 2.7
# ---
# There are a couple differences in the way Python 2 and Python 3 handle numbers. In Python 2, dividing two integers always results in an integer, while Python 3 always returns a float. This is fine when the result of your integer division is an integer, but it leads to quite different results when the answer is a decimal.

# %% [markdown]
# ### Division in Python 2.7

# %%
# Python 2.7
print 4/2
# Out:
#   File "<ipython-input-29-34fb21fb5506>", line 2
#     print 4/2
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(4/2)?

# %%
# Python 2.7
print 3/2
# Out:
#   File "<ipython-input-30-fab6f27a0757>", line 2
#     print 3/2
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(3/2)?

# %% [markdown]
# [Python2.7 online](https://www.tutorialspoint.com/execute_python_online.php)

# %% [markdown]
# ### Division in Python 3.3

# %%
# Python 3
print(4/2)

# %%
# Python 3
print(3/2)

# %% [markdown]
# If you are getting numerical results that you don't expect, or that don't make sense, check if the version of Python you are using is treating integers differently than you expect.

# %% [markdown]
# # More about print function

# %% [markdown]
# print() can accept any number of arguments

# %% [markdown]
# An example, print() with 2 arguments (str, str). A white space is added between two arguments.

# %%
print('Hello','World')

# %% [markdown]
# Another example, print() with 3 arguments (str, int, str)

# %%
print('Hello', 2, 'World')

# %% [markdown]
# Lastly, print() without an argument just print a blank line.

# %%
print('Hello')
print()
print('World')

# %% [markdown]
# Escape key in print statement is '\\'. If we want to print `"` inside a double quote string, use `\`. Use this technique if you could not solve exercise 8.

# %%
print("I say \"Hello World\".")

# %% [markdown]
# ---

# %% [markdown]
# # String Formating

# %% [markdown]
# String formatting lets you inject items into a string rather than trying to chain items together using commas or string concatenation. As a quick comparison, consider:

# %%
player = 'Thomas'
points = 33

# concatenation
print('Last night, ' + player + ' scored '+ str(points) +' points.') 

# print with multiple arguments 
print('Last night,', player, 'scored', points, 'points.')

# string formatting 1 using modulo % operator or string formatting operator
print('Last night, %s scored %d points.' % (player, points)) 

# string formatting 2 using str.format() method
print('Last night, {0} scored {1} points.'.format(player, points)) 

# string formatting 3 using f-strings
print(f'Last night, {player} scored {points} points.')

# %% [markdown]
# There are three ways to perform string formatting.
#
# The oldest method involves placeholders using the modulo % character.
# An improved technique uses the .format() string method.
# The newest method, introduced with Python 3.6, uses formatted string literals, called f-strings.
#
# As a introduction, in this notebook, we will cover only the first (oldest) method. Please refer the references for more information about str.format() method and f-strings.

# %% [markdown]
# Formatting with placeholders
# ---
#  You can use %s to inject strings into your print statements. The modulo % is referred to as a "string formatting operator".

# %%
print("I'm going to inject %s here." % 'something')

# %% [markdown]
# You can pass multiple items by placing them inside a tuple after the % operator.

# %%
print("I'm going to inject %s text here, and %s text here." %('some','more'))

# %% [markdown]
# You can also pass variable names:

# %%
x, y = 'some', 'more'
print("I'm going to inject %s text here, and %s text here."%(x,y))

# %% [markdown]
# Note that x, y in the previous cell is called 'Tuple'. The statement in line 1 is called 'Tuple Assignment'. It assigns 'some' to variable x and 'more' to variable y. We may do the same thing in two lines by:

# %%
# multiple assignments
x = 'some'
y = 'more'
print(x, y)

# tuple assignment
x, y = 'some', 'more'
print(x, y)

# %% [markdown]
# Format conversion methods.
#
# It should be noted that two methods %s and %r convert any python object to a string using two separate methods: str() and repr(). We will learn more about these functions later on in the course, but you should note that %r and repr() deliver the string representation of the object, including quotation marks and any escape characters.

# %%
print('He said his name was %s.' %'Fred')
print('He said his name was %r.' %'Fred')

# %% [markdown]
# As another example, \t inserts a tab into a string.

# %%
print('I once caught a fish %s.' %'this \tbig')
print('I once caught a fish %r.' %'this \tbig')

# %% [markdown]
# The %s operator converts whatever it sees into a string, including integers and floats. The %d operator converts numbers to integers first, without rounding. Note the difference below:

# %%
print('I wrote %s programs today.' %3.75)
print('I wrote %d programs today.' %3.75)

# %% [markdown]
# Padding and Precision of Floating Point Numbers
# Floating point numbers use the format. for example, %5.2f. Here, 5 would be the minimum number of characters the string should contain; these may be padded with whitespace if the entire number does not have this many digits. Next to this, .2f stands for how many numbers to show past the decimal point. Let's see some examples:

# %%
print('Floating point numbers: %5.2f' %(13.144))

# %%
print('Floating point numbers: %1.0f' %(13.144))

# %%
print('Floating point numbers: %1.5f' %(13.144))

# %%
print('Floating point numbers: %10.2f' %(13.144))

# %%
print('Floating point numbers: %25.2f' %(13.144))

# %% [markdown]
# **Multiple Formatting**
# Nothing prohibits using more than one conversion tool in the same print statement:

# %%
print('First: %s, Second: %5.2f, Third: %r' %('hi!',3.1415,'bye!'))

# %% [markdown]
# **Exercise 10**: Use string formatting to print *x*, *message* and *pi* to format bstring such that it has the same content as another string (*astring*)

# %%
astring = '   10 Hello 3.14'

# %%
###Add a formatting string on line 5 to make bstring having the same content as astring
x = 10
message = 'Hello'
pi = 3.1415
bstring = '   ' % (x, message, pi) # modify this line
print(astring)
print(bstring)
astring == bstring

# %% [markdown]
# **Ref:**
# 1. https://github.com/ehmatthes/intro_programming
# 2. https://github.com/jerry-git/learn-python3
# 3. https://courses.cs.washington.edu/courses/cse143/12wi/python.shtml
# 4. https://www.kaggle.com/ealtili/python-3-strings-with-formatting
